# %%
import pandas as pd
from  matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Read Data
data = pd.read_csv("c:\\All_Waste_Day.csv")
data
# Out:
#      Unnamed: 0            Country Economic_status  Coastal_population  \
# 0             0            Albania             LMI             2530533
# 1             1            Algeria             UMI            16556580
# 2             2             Angola             LMI             3790041
# 3             3           Anguilla             HIC               14561
# 4             4  Antigua & Barbuda             HIC               66843
# ..          ...                ...             ...                 ...
# 187         187               USVI             HIC              134219
# 188         188            Vanuatu             LMI              251851
# 189         189          Venezuela             HIC            16094897
# 190         190            Vietnam             LMI            55858245
# 191         191              Yemen             LMI             6048920
#
#           AWD  PW
# 0     1948510   9
# 1    19867896  12
# 2     1819220  13
# 3       30578  12
# ...

# %%
#Read first 20 rows
first_20 = data.head(20)
first_20
# Out:
#     Unnamed: 0                 Country Economic_status  Coastal_population  \
# 0            0                 Albania             LMI             2530533
# 1            1                 Algeria             UMI            16556580
# 2            2                  Angola             LMI             3790041
# 3            3                Anguilla             HIC               14561
# 4            4       Antigua & Barbuda             HIC               66843
# 5            5               Argentina             UMI            16449245
# 6            6                   Aruba             HIC              137910
# 7            7               Australia             HIC            17235954
# 8            8                 Bahamas             HIC              341145
# 9            9                 Bahrain             HIC              743574
# 10          10              Bangladesh              LI            70874124
# ...

# %%
#Information Of Data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          192 non-null    int64
#  1   Country             192 non-null    object
#  2   Economic_status     192 non-null    object
#  3   Coastal_population  192 non-null    int64
#  4   AWD                 192 non-null    int64
#  5   PW                  192 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 9.1+ KB

# %%
#Number of rows
len(data)
# Out:
# 192

# %%
#Number Of columns
len(data.columns)
# Out:
# 6

# %%
#number of rows and columns
data.shape
# Out:
# (192, 6)

# %%
#Number of elements
data.size
# Out:
# 1152

# %%
data.corr()
# Out:
#                     Unnamed: 0  Coastal_population       AWD        PW
# Unnamed: 0            1.000000           -0.018383  0.063644  0.090783
# Coastal_population   -0.018383            1.000000  0.827624 -0.092504
# AWD                   0.063644            0.827624  1.000000 -0.041263
# PW                    0.090783           -0.092504 -0.041263  1.000000

# %%
#To get Minimun,Maximum ,Mean,Median and Count
data.describe()
# Out:
#        Unnamed: 0  Coastal_population           AWD          PW
# count  192.000000        1.920000e+02  1.920000e+02  192.000000
# mean    95.500000        1.053535e+07  1.281152e+07   11.515625
# std     55.569776        3.069092e+07  3.575310e+07    3.320532
# min      0.000000        5.960000e+02  1.089000e+03    2.000000
# 25%     47.750000        1.679265e+05  3.198012e+05   11.000000
# 50%     95.500000        1.374844e+06  1.327021e+06   12.000000
# 75%    143.250000        7.115553e+06  9.354860e+06   13.000000
# max    191.000000        2.628924e+08  2.913466e+08   25.000000

# %%
first_20.plot(kind = 'bar',x = 'Country',y = 'AWD',color = "orange",stacked=True)
plt.show()

# %%
plt.bar(x = 'first_20.Country',y = 'first_20.AWD')
plt.bar(x = 'first_20.Country',y = 'first_20.PW',color = "orange",stacked=True)           
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-fda4554fedd3> in <module>
# ----> 1 plt.bar(x = 'first_20.Country',y = 'first_20.AWD',height = 2)
#       2 plt.bar(x = 'first_20.Country',y = 'first_20.PW',bottom = 'first_20.AWD',color = "orange",height = 2)
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...

# %%
#data.loc[data['PW'] >= 9] = True
#data

# %%
#first_20.loc[first_20['PW'] <= 9, 'equal_or_lower_than_9?'] = 'True' 
#first_20.loc[first_20['PW'] > 9, 'equal_or_lower_than_9?'] = 'False' 
#print(first_20)
