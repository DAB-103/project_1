# %%
import pandas as pd
from  matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Read Data
data = pd.read_csv("c:\\Country_plastic_details.csv")
data
# Out:
#                Country Economic_status  Coastal_population    WG   PWS   IMW  \
# 0              Albania             LMI           2530533.0  0.77   9.0  45.0
# 1              Algeria             UMI          16556580.0  1.20  12.0  58.0
# 2               Angola             LMI           3790041.0  0.48  13.0  71.0
# 3             Anguilla             HIC             14561.0  2.10  12.0   2.0
# 4    Antigua & Barbuda             HIC             66843.0  5.50  12.0   6.0
# ..                 ...             ...                 ...   ...   ...   ...
# 188            Vanuatu             LMI            251851.0  3.28   9.0  81.0
# 189          Venezuela             HIC          16094897.0  2.10  12.0   5.0
# 190            Vietnam             LMI          55858245.0  0.79  13.0  86.0
# 191              Yemen             LMI           6048920.0  0.79  13.0  73.0
# 192                NaN             NaN                 NaN   NaN   NaN   NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             192 non-null    object
#  1   Economic_status     192 non-null    object
#  2   Coastal_population  192 non-null    float64
#  3   WG                  192 non-null    float64
#  4   PWS                 192 non-null    float64
#  5   IMW                 192 non-null    float64
#  6   LW                  192 non-null    float64
#  7   WG.1                192 non-null    float64
#  8   PWG                 192 non-null    float64
#  9   IMPW                192 non-null    float64
#  10  PWL                 192 non-null    float64
#  11  MPW                 193 non-null    object
#  12  MPW2010             193 non-null    int64
#  13  MPW2025             193 non-null    int64
# dtypes: float64(9), int64(2), object(3)
# memory usage: 21.2+ KB

# %%
data.corr()
# Out:
#                     Coastal_population        WG       PWS       IMW  LW  \
# Coastal_population            1.000000 -0.107846 -0.092504  0.146266 NaN
# WG                           -0.107846  1.000000  0.189471 -0.391251 NaN
# PWS                          -0.092504  0.189471  1.000000 -0.158185 NaN
# IMW                           0.146266 -0.391251 -0.158185  1.000000 NaN
# LW                                 NaN       NaN       NaN       NaN NaN
# WG.1                          0.827624  0.043619 -0.041263 -0.021541 NaN
# PWG                           0.770921  0.069419  0.077224 -0.040084 NaN
# IMPW                          0.770741 -0.068956 -0.006944  0.240860 NaN
# PWL                           0.770921  0.069419  0.077224 -0.040084 NaN
# MPW2010                       0.783669 -0.064308 -0.003530  0.233113 NaN
# MPW2025                       0.820618 -0.101696 -0.012326  0.260045 NaN
#
#                         WG.1       PWG      IMPW       PWL   MPW2010   MPW2025
# ...

# %%
data.describe()
# Out:
#        Coastal_population          WG         PWS         IMW     LW  \
# count        1.920000e+02  192.000000  192.000000  192.000000  192.0
# mean         1.053535e+07    1.642760   11.515625   33.973958    2.0
# std          3.069092e+07    1.365327    3.320532   34.213288    0.0
# min          5.960000e+02    0.140000    2.000000    0.000000    2.0
# 25%          1.679265e+05    0.790000   11.000000    0.000000    2.0
# 50%          1.374844e+06    1.240000   12.000000   22.000000    2.0
# 75%          7.115553e+06    2.100000   13.000000   73.250000    2.0
# max          2.628924e+08   14.400000   25.000000   88.000000    2.0
#
#                WG.1           PWG          IMPW            PWL       MPW2010  \
# count  1.920000e+02  1.920000e+02  1.920000e+02     192.000000  1.930000e+02
# mean   1.281152e+07  1.420189e+06  4.262948e+05   28403.791667  3.302101e+05
# std    3.575310e+07  4.143231e+06  1.925674e+06   82864.637909  2.392411e+06
# ...

# %%
PWL_top = data.sort_values(by=['PWL'],ascending=False)

# %%
Top_10 = PWL_top.head(10)

# %%
Top_10.plot(kind = 'bar',x = 'Country',y = 'PWL',color = "orange")
plt.ylabel("Plastic_waste_littered_[kg/day]")
plt.title("Plastic waste generation of top 10 countries")
# Out:
# Text(0.5, 1.0, 'Plastic waste generation of top 10 countries')
