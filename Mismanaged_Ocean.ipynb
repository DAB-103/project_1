# %%
import pandas as pd
from  matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Read Data
data = pd.read_csv("c:\\Mismanaged_Ocean.csv")
data
# Out:
#      Unnamed: 0            Country  Mismanaged_plastic_waste_kg/person/day  \
# 0             0            Albania                                    0.03
# 1             1            Algeria                                    0.09
# 2             2             Angola                                    0.05
# 3             3           Anguilla                                    0.01
# 4             4  Antigua & Barbuda                                    0.05
# ..          ...                ...                                     ...
# 187         187               USVI                                    0.01
# 188         188            Vanuatu                                    0.25
# 189         189          Venezuela                                    0.02
# 190         190            Vietnam                                    0.09
# 191         191              Yemen                                    0.08
#
#      Mismanaged_plastic_waste_lb/person/day  MPWO
# ...

# %%
data.corr()
# Out:
#                                         Unnamed: 0  \
# Unnamed: 0                                1.000000
# Mismanaged_plastic_waste_kg/person/day    0.194219
# Mismanaged_plastic_waste_lb/person/day    0.192967
# MPWO                                      0.180638
#
#                                         Mismanaged_plastic_waste_kg/person/day  \
# Unnamed: 0                                                            0.194219
# Mismanaged_plastic_waste_kg/person/day                                1.000000
# Mismanaged_plastic_waste_lb/person/day                                0.999777
# MPWO                                                                  0.993879
#
#                                         Mismanaged_plastic_waste_lb/person/day  \
# Unnamed: 0                                                            0.192967
# Mismanaged_plastic_waste_kg/person/day                                0.999777
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 5 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              192 non-null    int64
#  1   Country                                 192 non-null    object
#  2   Mismanaged_plastic_waste_kg/person/day  192 non-null    float64
#  3   Mismanaged_plastic_waste_lb/person/day  192 non-null    float64
#  4   MPWO                                    192 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 7.6+ KB

# %%
 data = data.head(15)
 data
# Out:
#     Unnamed: 0            Country  Mismanaged_plastic_waste_kg/person/day  \
# 0            0            Albania                                    0.03
# 1            1            Algeria                                    0.09
# 2            2             Angola                                    0.05
# 3            3           Anguilla                                    0.01
# 4            4  Antigua & Barbuda                                    0.05
# 5            5          Argentina                                    0.03
# 6            6              Aruba                                    0.01
# 7            7          Australia                                    0.00
# 8            8            Bahamas                                    0.01
# 9            9            Bahrain                                    0.02
# 10          10         Bangladesh                                    0.03
# 11          11           Barbados                                    0.03
# ...

# %%
plt.hist(data.MPWO)
# Out:
# (array([5., 0., 1., 0., 5., 0., 3., 0., 0., 1.]),
#  array([0.   , 0.005, 0.01 , 0.015, 0.02 , 0.025, 0.03 , 0.035, 0.04 ,
#         0.045, 0.05 ]),
#  <BarContainer object of 10 artists>)
